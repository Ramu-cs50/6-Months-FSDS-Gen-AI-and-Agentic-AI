# %%
#Last spaces are printed as it is
txt="   abc def ghi      "
txt.lstrip()
# Out:
# 'abc def ghi      '

# %%
#For strip() function front and the back spaces are removed
txt.strip()
# Out:
# 'abc def ghi'

# %%
mystr="My favourite TV series is \"Game of Thrones\""
print(mystr)
# Out:
# My favourite TV series is "Game of Thrones"

# %%
list1=[]
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,30,60] # list with integers
list3=[10.22, 9.87, 6.23, 7.78, 9.32] # list with float values
list4=["Ramu", "Sai", "Brothers"] #List with String values
list5=["Ramu", 34, [23, 45], [89,32]] #Nested lists
list6=[39, "Sai", 23,1]  #List with mixed datatypes
list7=["Ramu", 32, [10,20], [30, 40], {"Family", "Friends", "Cousins"}] #List with various datatypes and nested lists

# %%
#retriving 1st element 
list2[0]
# Out:
# 10

# %%
# retriving first elementt of the first list for the word Ramu in list4 - Nested List
list4[0][0]
# Out:
# 'R'

# %%
#Last item of the list
list4[-1]
# Out:
# 'Brothers'

# %%
#List Slicing
#Arranging list in an ascending order
my_list1=[43,2,51, 23, 46,  87, 2, 57,90]
my_list1.sort()
my_list1
# Out:
# [2, 2, 23, 43, 46, 51, 57, 87, 90]

# %%
#Arranging list in an descending order
my_list1.sort(reverse=True)
my_list1
# Out:
# [90, 87, 57, 51, 46, 43, 23, 2, 2]

# %%
my_list2=[32, 54, 2, 45, 55, 876, 23, 5,465, 654, 63, 63, 66 ,90, 221]
sorted(my_list2) # returns a new  sorted list and doesn't change the origiinal
my_list2
# Out:
# [32, 54, 2, 45, 55, 876, 23, 5, 465, 654, 63, 63, 66, 90, 221]

# %%
my_list2
# Out:
# [32, 54, 2, 45, 55, 876, 23, 5, 465, 654, 63, 63, 66, 90, 221]
