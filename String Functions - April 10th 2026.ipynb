# %%
p=0
q=20
r=20

# %%
p=q=r=20

# %%
p1,q1,r1=20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p1,q1,r1=20
#
# TypeError: cannot unpack non-iterable int object

# %%
id(p)
# Out:
# 140711327540744

# %%
id(q)
# Out:
# 140711327540744

# %%
id(r)
# Out:
# 140711327540744

# %%
p=10
q=11
r=12
print(id(p))
print(id(q))
print(id(r))
# Out:
# 140711327540424
# 140711327540456
# 140711327540488

# %%
p1,q1,r1=3,4,5
print(p1,q1,r1)
# Out:
# 3 4 5

# %%
s='Hello Python'
s
# Out:
# 'Hello Python'

# %%
len(s)
# Out:
# 12

# %%
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'n'

# %%
s[5:]
# Out:
# ' Python'

# %%
s[0:5]
# Out:
# 'Hello'

# %%
s[6:9]
# Out:
# 'Pyt'

# %%
s[-5:-1]
# Out:
# 'ytho'

# %%
s[0:]
# Out:
# 'Hello Python'

# %%
s[:6]
# Out:
# 'Hello '

# %%
s[2:9]
# Out:
# 'llo Pyt'

# %%
#String reverse slicing
s[::-1]
# Out:
# 'nohtyP olleH'

# %%
s[::-2]
# Out:
# 'nhy le'

# %%
#Slicing with Step index
s[::]
# Out:
# 'Hello Python'

# %%
s[3:10:2]
# Out:
# 'l yh'

# %%
s[2:11:4]
# Out:
# 'lPo'

# %%
s1="DataScience"
s1
# Out:
# 'DataScience'

# %%
s1[:9]
# Out:
# 'DataScien'

# %%
s1[1:7:2]
# Out:
# 'aac'

# %%
s1[8:-2:2]
# Out:
# 'n'

# %%
s1[1:5:6]
# Out:
# 'a'

# %%
s1[2:9:3]
# Out:
# 'tcn'

# %%
s1[1:-2:4]
# Out:
# 'ac'

# %%
s1[-1:-9:-2]

s1[-4:6:-2]

import numpy as np

# %%
#nan is not a number which is in numpy even it is not equal to itself
import pandas as pd
import numpy as np
np.nan==np.nan
# Out:
# False

# %%
#String Concatenation or adding 2 strings
s1= 'Hello'
s2='World'
s3=s1+s2
s3
# Out:
# 'HelloWorld'
