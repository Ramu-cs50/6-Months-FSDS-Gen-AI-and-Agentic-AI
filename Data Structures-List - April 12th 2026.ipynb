# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
l=[]
l
# Out:
# []

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
#List only takes 1 argument
l.append(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l.append(10,20)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(20)
l
# Out:
# [10, 20, 30, 40, 50, 20, 20, 20, 20]

# %%
l=[10,20,30,40,50]
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(60)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l.copy
# Out:
# <function list.copy()>

# %%
l.count
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l.pop
l
# Out:
# [10, 20, 30, 40, 50, 60]
