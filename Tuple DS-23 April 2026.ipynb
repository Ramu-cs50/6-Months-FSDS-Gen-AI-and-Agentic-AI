# %%
#Tuple DS is defined in () - Open Brackets, and it is not changable
#It has onl 2 finctions - Index() and count()
t1=(10,20,30)
type(t1)
# Out:
# tuple

# %%
print(t1)
# Out:
# (10, 20, 30)

# %%
t1.count(t1)
# Out:
# 0

# %%
t1.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(10)
# Out:
# 0

# %%
for i in t1:
    print(i)
# Out:
# 10
# 20
# 30

# %%
# using enumerate in tuple
for i in enumerate(t1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)

# %%
#As a tuple is not changeable, it just repeats the number multiple times. 
t2=4*t1
t2
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t2.remove(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t2.remove(20)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
del t2

# %%
print(t2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(t2)
#
# NameError: name 't2' is not defined

# %%
t2=(10,20,30)
t2
t2=(40,50,60)
t2
# Out:
# (40, 50, 60)

# %%
#It is error because we cannot update the values in tuple
t2[0]=90
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 t2[0]=90
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Tuple Practice
tup1=tuple()  # Empty Tuple
tup2=(10, 30, 60) #Tuple of integer Numbers
tup3=(12.3, 43.1, 23.22) #Tuple of FLoat Numers
tup4=("Ramu", "Sai", "Brothers") #Tuple of String Values
tup5=('Ramu', 32, (32, 21), (43.1, 23)) #Nested Tuple
tup6=(320, "Ramu", 32.1) #Tuple with different values
tup7=("Ramu", 42, [40, 23], [25, 32], ("Ramu", "Sai", "Brothers"), (23, 43, 12))
len(tup7)
# Out:
# 6

# %%
print(tup7[4][0])
print(tup7[4][1])
print(tup7[4][2])
# Out:
# Ramu
# Sai
# Brothers

# %%
#Tuple Indexing  on tup4
print(tup4[0])
# Out:
# Ramu

# %%
del tup2

# %%
print(tup4)
# Out:
# ('Ramu', 'Sai', 'Brothers')

# %%
#List membership checking for an element is present in tuple or not
if 'Ramu' in tup4:
    print("Ramu is present in the tuple")
else:
    print("Ramu is not present in the tuple")
# Out:
# Ramu is present in the tuple

# %%
#sorting of Tuple
sorted(tup3,reverse=False)
# Out:
# [12.3, 23.22, 43.1]
