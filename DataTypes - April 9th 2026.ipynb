# %% [markdown]
# ##2026-04-09(YYYY-MM-DD): PYTHON DATATYPES

# %%
i=32

i
# Out:
# 32

# %%
type(i)
# Out:
# int

# %%
#This shows error because variable inside function is an integer
len(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 len(i)
#
# TypeError: object of type 'int' has no len()

# %%
f=110.32
f
# Out:
# 110.32

# %%
type(f)
# Out:
# float

# %%
f1=1e0
f1
# Out:
# 1.0

# %%
f4=1E5
f4
# Out:
# 100000.0

# %%
f2=1e3
f2
# Out:
# 1000.0

# %%
f6=1e1
f6
# Out:
# 10.0

# %%
a=20
b=30
c=print(a+b)
d=print(a-b)
# Out:
# 50
# -10

# %%
print(a*b)
# Out:
# 600

# %%
print(a/b)
# Out:
# 0.6666666666666666

# %%
print(10)
# Out:
# 10

# %%
print('Harry Potter', 23, 2.4)
# Out:
# Harry Potter 23 2.4

# %%
a=20
b=30
sum=a+b
print(" The sum of 1st Number", a, "and the second number", b, "is", sum)
# Out:
#  The sum of 1st Number 20 and the second number 30 is 50

# %%
name="Python"
age=24
city="Hyderabad"
print("Hello my name is",name,",I am", age," years old and I am from", city,".")
# Out:
# Hello my name is Python ,I am 24  years old and I am from Hyderabad .

# %%
#Format strings
num1=10
num2=20
num3=50
sum=num1+num2+num3
print('The addition of {}, {} and {} is {}'.format(num1,num2,num3,sum))
# Out:
# The addition of 10, 20 and 50 is 80

# %%
#complex datatype
c=1+3j
c
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %% [markdown]
# c.imag

# %%
a=3+4j
b=9+2j
print(a+b)
print(a-b)
# Out:
# (12+6j)
# (-6+2j)

# %%
def team(c):
    print("hello")
    a=10
    b=20
    c=a+b
    return c
team(c)
# Out:
# hello
# 30

# %%
b=True
c=False
b==c
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
#Type Con
True+False-True*False-3+ True*True
# Out:
# -1

# %%
False-False
# Out:
# 0
