# %%
#Dictionary is declared as Keys:Values and it is mutable
d={}
type(d)
# Out:
# dict

# %%
d1={1:"One", 2:"Two", 3:"Three"}

# %%
d1
# Out:
# {1: 'One', 2: 'Two', 3: 'Three'}

# %%
d2={"One":1, "two":2, "Three":3}
d2
# Out:
# {'One': 1, 'two': 2, 'Three': 3}

# %%
d1.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
d1.values()
# Out:
# dict_values(['One', 'Two', 'Three'])

# %%
len(d1.items())
# Out:
# 3

# %%
#It teturns all the keys and values present in the dictionary
d1.items()
# Out:
# dict_items([(1, 'One'), (2, 'Two'), (3, 'Three')])

# %%
#Dictionary with a list  inside it
d3={1:"One", 2:"Two", "A":["Amit","Afraz","Alfred"]}
d3
# Out:
# {1: 'One', 2: 'Two', 'A': ['Amit', 'Afraz', 'Alfred']}

# %%
print(d3["A"][2][0])
print(d3["A"][2][1])
print(d3["A"][2][2])
print(d3["A"][2][3])
print(d3["A"][2][4])
print(d3["A"][2][5])
# Out:
# A
# l
# f
# r
# e
# d

# %%
#Dict with a List and a tuple
d4={1:"One", 2:"Two", "Siblings":("Ramu-Sai","Sree-Sahiti","Karthik-Swetha", "Bharani-Poornima"), "Cousins":["Swetha","Karthik","Sreeram","Lalli","Sailu","Suppi"] 
}

# %%
d4.keys()
# Out:
# dict_keys([1, 2, 'Siblings', 'Cousins'])

# %%
d4.values()
# Out:
# dict_values(['One', 'Two', ('Ramu-Sai', 'Sree-Sahiti', 'Karthik-Swetha', 'Bharani-Poornima'), ['Swetha', 'Karthik', 'Sreeram', 'Lalli', 'Sailu', 'Suppi']])

# %%
#Creating a dict with a sequence of keys
keys={'a','b','c','d','e'}
values=[10,20,40]
keys
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
d4=dict.fromkeys(keys, values)

# %%
d4
# Out:
# {'a': [10, 20, 30, 30, 40],
#  'c': [10, 20, 30, 30, 40],
#  'b': [10, 20, 30, 30, 40],
#  'd': [10, 20, 30, 30, 40],
#  'e': [10, 20, 30, 30, 40]}

# %%
#Inderting a value to the variable inside a dctionary
values.insert(2,30)

# %%
#Access  item using get() and index
d2
# Out:
# {'One': 1, 'two': 2, 'Three': 3}

# %%
d2["One"]
# Out:
# 1

# %%
d2.get("One")
# Out:
# 1

# %%
d2.pop('One')
# Out:
# 1

# %%
d2
# Out:
# {'two': 2, 'Three': 3}

# %%
d5={"Name":"Ramu", "Age":24, "DOB":"24/08/2026", "Height":6}
d5
# Out:
# {'Name': 'Ramu', 'Age': 24, 'DOB': '24/08/2026', 'Height': 6}

# %%
ud5={'DOB':"24-08-2001"}

# %%
d5.update(ud5)

# %%
d5
# Out:
# {'Name': 'Ramu', 'Age': 24, 'DOB': '24-08-2001', 'Height': 6}

# %%
#Adding items to the dict
d5
# Out:
# {'Name': 'Ramu', 'Age': 24, 'DOB': '24-08-2001', 'Height': 6}

# %%
#Adding items to the dict
d5["Job"]="Unemployed"

# %%
d5
# Out:
# {'Name': 'Ramu',
#  'Age': 24,
#  'DOB': '24-08-2001',
#  'Height': 6,
#  'Job': 'Unemployed'}

# %%
d5
# Out:
# {'Name': 'Ramu',
#  'Age': 24,
#  'DOB': '24-08-2001',
#  'Height': 6,
#  'Job': 'Unemployed'}

# %%
d6=d5.copy()

# %%
d6
# Out:
# {'Name': 'Ramu',
#  'Age': 24,
#  'DOB': '24-08-2001',
#  'Height': 6,
#  'Job': 'Unemployed'}

# %%
d5==d6
# Out:
# True

# %%
id(d5)==id(d6)
# Out:
# True

# %%
d6
# Out:
# {'Name': 'Ramu',
#  'Age': 24,
#  'DOB': '24-08-2001',
#  'Height': 6,
#  'Job': 'Unemployed'}

# %%
for i in d6:
    print(i, ":", d6[i])
# Out:
# Name : Ramu
# Age : 24
# DOB : 24-08-2001
# Height : 6
# Job : Unemployed
