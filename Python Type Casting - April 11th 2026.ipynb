# %%
#Python Type Casting or Type Conversion
#We will convert one data type to anotherv data type

# %%
#Integer Typecasting we wont be able to do Text and Complex Numbers
int(2.9)
# Out:
# 2

# %%
int(22.3,5.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(22.3,5.3)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
print(int(2.9))
print(int(True))
print(int("1"))
print(int(2+3j))
# Out:
# 2
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 print(int(True))
#       3 print(int("1"))
# ----> 4 print(int(2+3j))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
#Float Typecasting 
#In float we wont be able to convert String and Complex Numbers to Float
print(float(2))
print(float(False))
print(float("1"))
# Out:
# 2.0
# 0.0
# 1.0

# %%
#Complex Typecasting
# Here we wont be able to comvert from string to complex.
#We can pass only one value in string type and it is for the real part of the complex number.
complex(10)
# Out:
# (10+0j)

# %%
#We can also pass 2 arguments as one is for real part and the other is for imaginary part
complex(10,2)
# Out:
# (10+2j)

# %%
#We cannot more than 2 arguments as it can maximum take 2 arguments
complex(2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 #We cannot more than 2 arguments as it can maximum take 2 arguments
# ----> 2 complex(2,3,4)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2,1.1)
# Out:
# (2+1.1j)

# %%
#We can even convert boolean to complex
complex(True,False)
# Out:
# (1+0j)

# %%
#We can only pass one string in number argument as it willbe used as Real Number 
complex('1','2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 #We can only pass one string in number argument as it willbe used as Real Number
# ----> 2 complex('1','2')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(1+"4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 complex(1+"4")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#One number in text for Real part of  the complex number
complex('1')
# Out:
# (1+0j)

# %%
#Boolean Typecasting
#We will  be getting true if we give an argument to convert to any other data type.
# It will be false if  we dont give any arguments in side function
bool(2)
# Out:
# True

# %%
bool("1")
# Out:
# True

# %%
bool("Hello")
# Out:
# True

# %%
bool(1.1)
# Out:
# True

# %%
print(bool(10))
print(bool("10"))
print(bool(3.2))
print(bool(True))
print(bool("Hello World"))
print(bool(1+4j))
bool()
# Out:
# True
# True
# True
# True
# True
# True
# False

# %%
# Out:
# 10
# 10
# 10.1
# Hello World
# (1+1j)
# True

# %%
str(10)
str("10")
str(10.1)
str("Hello World")
str(1+1j)
str(True)
str()
# Out:
# ''

# %%
str(10)
# Out:
# '10'

# %%
str(False)
# Out:
# 'False'

# %%
str(10.10)
# Out:
# '10.1'

# %%
str(2+3j)
# Out:
# '(2+3j)'

# %%
str("Heloow")
# Out:
# 'Heloow'

# %%
#Int casting practice
print(int(2))
print(int('3'))
print(int(2.5))
print(int(True))
print(int(3+3j)) # complex is not allowed
print(int("Hellow"))#Str is not allowed
# Out:
# 2
# 3
# 2
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 6
#       4 print(int(2.5))
#       5 print(int(True))
# ----> 6 print(int(3+3j))
#       7 print(int("Hellow"))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
#Float casting practice
print(float(19))
print(float("19"))
print(float(True))
print(float(3+1j)) #complex is not allowed
print(float("Hi"))  #String is not allowed
# Out:
# 19.0
# 19.0
# 1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 5
#       3 print(float("19"))
#       4 print(float(True))
# ----> 5 print(float(3+1j))
#       6 print(float("Hi"))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
#Complex casting practice
print(complex(2))
print(complex("2"))
print(complex(3.2))
print(complex(3+2j))
print(complex(True))
print(complex(3,4))
print(complex("4"))
print(complex(0))
print(complex(2*True,4*True))
# Out:
# (2+0j)
# (2+0j)
# (3.2+0j)
# (3+2j)
# (1+0j)
# (3+4j)
# (4+0j)
# 0j
# (2+4j)

# %%
#String Casting Practice
print(str(2))
print(str(True))
print(str(3.3))
print(str("Hello"))
print(str(8+3j))
print(str("3"))
print(str())
# Out:
# 2
# True
# 3.3
# Hello
# (8+3j)
# 3
