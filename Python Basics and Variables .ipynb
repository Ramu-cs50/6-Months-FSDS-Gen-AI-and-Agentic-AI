# %%
a=10  #variable declaration

# %%
a
# Out:
# 10

# %%
id(a)  #address of memory location
# Out:
# 140734650788568

# %%
v=5

# %%
v
# Out:
# 5

# %%
id(v)
# Out:
# 140734650788408

# %%
v1=10

# %%
v1
# Out:
# 10

# %%
v*=78

# %%
v_=5

# %%
v_
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
ELSE=9
ELSE
# Out:
# 9

# %%
else=9
# Out:
#   Cell In[26], line 1
#     else=9
#     ^
# SyntaxError: invalid syntax

# %%
Else=9
Else
# Out:
# 9

# %%
spam=10
spam
# Out:
# 10

# %%
prefix='py'
prefix='thon'

# %%
prefix
# Out:
# 'thon'

# %%
'py'+ prefix
# Out:
# 'python'

# %%
#this is first commment
spam=100 #this is second comment
text="#this is not a comment"
spam
text
# Out:
# '#this is not a comment'

# %%
text="#this is not a \ncomment"
text
# Out:
# '#this is not a \ncomment'

# %%
task = 'I wake at 2 o\'clock in the morning'
print(task)
# Out:
# I wake at 2 o'clock in the morning

# %%
ipl='''It has a total of "8" teams'''
ipl
# Out:
# 'It has a total of "8" teams'

# %%
#Trying to use singlequote with escape sequences
Sunrise = 'Today the sunrise took place at 8 o\'clock in the morning'
print(Sunrise)
# Out:
# Today the sunrise took place at 8 o'clock in the morning

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
#Trying to use Double quote with escape sequences
Rohit="He is called \"Mumbai-Cha-Raja\" for Mumbai Indians"
print(Rohit)
# Out:
# He is called "Mumbai-Cha-Raja" for Mumbai Indians

# %%
#escape sequence for the sentence to be in the next line
print("Hello \nWorld")
# Out:
# Hello
# World

# %%
#escape sequence for tab space in the text
print("2023: \tSales data")
# Out:
# 2023: 	Sales data

# %%
5+5
# Out:
# 10

# %%
5*5
# Out:
# 25

# %%
# ** represent the power for the number so here it is 5 power 5
5**5
# Out:
# 3125

# %%
#It gives the entire value from the output
11/2
# Out:
# 5.5

# %%
#It gives the integer value from the output
11//2
# Out:
# 5

# %%
# follows bodmas rule for calculations
(5*2)+3-11*3+(3*4-2)+15
# Out:
# 5

# %%
leng=10
bre=5
perimeter=leng*bre
print(perimeter)
# Out:
# 50

# %%
#Escape sequence for single quotesb
print("\"Yes,\" they said")
# Out:
# "Yes," they said

# %%
#escape sequence for double quotes
print("Isn\'t they said \"YES\"")
# Out:
# Isn't they said "YES"

# %%
# without print special character will be printed and with print keyword they will be interrupted
r=("First Line\nSecond Line")
r
# Out:
# 'First Line\nSecond Line'

# %%
3*"JAI" + 3*"SRI" + 3*"RAM"
# Out:
# 'JAIJAIJAISRISRISRIRAMRAMRAM'

# %%
prefix="py"
prefix="thon"
# Out:
# "py"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 3
#       1 prefix="py"
#       2 prefix="thon"
# ----> 3 print("\"py\"")+ prefix
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
#words which are beside with single quotes will be concatenated automatically
'I ' 'love ' 'you '
# Out:
# 'I love you '
