# %%
import math
a=25.42
math.sqrt(a)
# Out:
# 5.041825066382213

# %%
math.ceil(a)
# Out:
# 26

# %%
math.floor(a)
# Out:
# 25

# %%
math.pow(3,4)
# Out:
# 81.0

# %%
math.e
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
import math as m
a,b=25.234,26143
print(m.sqrt(a))
print(m.ceil(a))
print(m.floor(b))
print(m.pow(a,6))
# Out:
# 5.023345498768724
# 26
# 26143
# 258176430.68370995

# %% [markdown]
# #INPUT FUNCTION

# %%
#INput always return STRING
a=int(input("Enter 1st Value"))
b=int(input("Enter 2nd Value"))
c=a+b
print(c)
# Out:
# Enter 1st Value 4
# Enter 2nd Value 4
# 8

# %%
string=input("Enter a string")
string
# Out:
# Enter a string Ramu
# 'Ramu'

# %%
#Eval function will help us to resolve complex arithmatic operations in expressions
result=eval(input("Enter operation to be performed"))
result
# Out:
# Enter operation to be performed 5+6-3*6+3**3
# 20
